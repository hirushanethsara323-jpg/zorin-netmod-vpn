# %% [markdown]
# # Zorin NetMod VPN - Colab Test\n[Open in Colab](https://colab.research.google.com/github/hirushanethsara323-jpg/zorin-netmod-vpn/blob/main/colab.ipynb)

# %%
# !git clone https://github.com/hirushanethsara323-jpg/zorin-netmod-vpn.git
# %cd zorin-netmod-vpn
# !pip install paramiko websockets
# !python3 -m netmod.cli --list-configs
